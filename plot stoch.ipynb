# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
results = np.load('res3201')

# Data is printed from geekfile.npy
print("The data is printed from npfile.npy")

det_results = np.load('resdet3201')

# Data is printed from geekfile.npy
print("The data is printed from npfile.npy")
# Out:
# The data is printed from npfile.npy
# The data is printed from npfile.npy

# %%
#print(results[0])
x1 = results[7][0]
y1 = results[7][1]
z1 = results[7][2]
x = results[1][0]
y = results[1][1]
z = results[1][2]

# %%
fig,(ax1,ax2) = plt.subplots(nrows=1,ncols=2, figsize=(18, 9), tight_layout=False)
#ax1.scatter(ic2[0],ic2[1], label='Initial position', alpha = 0.85)
ax1.set_title('Precession with and without stochastic noise')
ax1.plot(det_results[0],det_results[1], linewidth =0.8, label='Deterministic (without rotation)', alpha = 0.85, color='blue')
ax1.plot(x,y, label='Sigma = 0.02', linewidth=0.3, color='orange', alpha = 0.90)
ax1.legend()
ax1.grid()
ax2.plot(det_results[0],det_results[1], linewidth =0.8, label='Deterministic (without rotation)', color='blue')
ax2.plot(x1,y1, label='Sigma = 0.08',linewidth=0.4, color='orange')
ax2.set_title('Precession with and without stochastic noise')
ax2.legend()
ax2.grid()
plt.show()
fig.savefig("qqq.png")
# Out:
# C:\Users\piatt\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
